# %%
import pickle
import pandas as pd
import numpy as np

# %%
Xy_test_aa = pd.read_csv("Xy_test.csv")

# %%
X_test = Xy_test_aa.iloc[:,:-1]
y_test = Xy_test_aa.iloc[:,-1]

# %%
X_test
# Out:
#      chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0           -0.190921         0.497513  0.856328 -0.307767
# 1           -0.705910         1.276524 -0.553290 -0.439650
# 2            0.200638         0.947305 -0.752767 -0.433216
# 3            0.457995         0.235012  0.647645  0.654434
# 4            0.403115         0.527785 -0.033084 -0.122074
# ..                ...              ...       ...       ...
# 994          0.361102        -0.339933  0.138413 -0.029374
# 995         -0.354484        -0.486155  1.060989  0.078498
# 996         -1.115917         0.670937 -1.233578 -0.550960
# 997         -0.327370         1.031480  0.507046  0.438850
# 998         -1.501822        -0.424972 -1.444802 -0.536938
#
#      spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                  1.578576               0.322970                 1.896166
# 1                  2.476527               0.024962                 2.334708
# 2                  0.419776               1.655229                 1.121596
# 3                  0.320163              -0.404765                 0.081464
# 4                  0.218807              -0.054397                 0.289764
# ..                      ...                    ...                      ...
# 994               -0.095071               0.521655                 0.084859
# 995                0.276789              -0.649913                 0.186171
# 996               -1.518207              -0.808895                -1.116982
# 997               -0.494185               1.244002                -0.623448
# 998               -0.902436              -0.603219                -1.285952
#
#      spectral_bandwidth_var  rolloff_mean  rolloff_var  ...  mfcc16_mean  \
# 0                  0.066536      1.877364    -0.004520  ...    -0.729045
# 1                 -0.710806      2.364000    -0.764069  ...    -1.582751
# 2                  2.281659      0.666121     2.836340  ...    -0.404243
# 3                 -0.537576      0.280313    -0.604025  ...     0.875043
# 4                 -0.391046      0.425376    -0.456622  ...     0.744751
# ..                      ...           ...          ...  ...          ...
# 994               -0.281272      0.111091     0.072867  ...    -0.290236
# 995               -0.943665      0.408731    -0.822668  ...     1.363349
# 996               -0.354635     -1.407527    -0.585042  ...    -0.414376
# 997                1.011344     -0.541641     0.612821  ...     0.519017
# 998               -0.344753     -1.039827    -0.681098  ...     0.063649
#
#      mfcc16_var  mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  \
# 0      0.448346    -0.301005    0.088114     0.488690    0.067097
# 1     -0.590022     0.577039   -0.520509     0.843710   -0.050255
# 2      0.105645    -0.676465    0.307438    -0.177594   -0.166756
# 3     -0.456332    -0.606393   -0.614830    -0.119796   -0.093524
# 4     -0.037636    -0.232036    0.606131     0.034778   -0.638722
# ..          ...          ...         ...          ...         ...
# 994   -0.610116    -0.514593   -0.541216    -0.068948   -0.569445
# 995    0.262615     0.139082   -0.238903     1.821206   -0.428615
# 996   -0.695091    -0.083050   -0.572266     0.666949    0.527153
# 997    2.192150    -0.375639   -0.290807    -0.791234   -0.610295
# 998    1.537312     0.453367    1.016004    -0.637947    0.198084
#
#      mfcc19_mean  mfcc19_var  mfcc20_mean  mfcc20_var
# 0       0.769328    0.698413     0.116609   -0.278356
# 1       1.704421   -0.075965     1.339031   -0.283492
# 2       1.362335    1.683163     0.640323    0.505634
# 3       0.664381   -0.449732     1.122482    0.083922
# 4      -0.887771    0.362257     0.603048    0.031929
# ..           ...         ...          ...         ...
# 994    -1.344699    0.397351     0.831254   -0.529894
# 995     0.462848    0.839443    -0.123797    0.099759
# 996     2.844366    1.006903     1.063897    0.547844
# 997    -0.284236    0.078789     1.063246    0.458261
# 998     0.179352    0.717183    -0.326505    0.124471
#
# [999 rows x 57 columns]

# %%
y_test
# Out:
# 0      7
# 1      3
# 2      8
# 3      0
# 4      9
#       ..
# 994    9
# 995    2
# 996    0
# 997    2
# 998    1
# Name: label, Length: 999, dtype: int64

# %%
with open('model_cat.pkl', 'rb') as f:
    cat = pickle.load(f)

# %%
with open('model_rforest.pkl', 'rb') as f:
    rforest = pickle.load(f)

# %%
with open('model_ada.pkl', 'rb') as f:
    ada = pickle.load(f)

# %%
with open('model_sgd.pkl', 'rb') as f:
    sgd = pickle.load(f)

# %%
with open('model_gaussian.pkl', 'rb') as f:
    g_NaiveB = pickle.load(f)

# %%
y_pred = cat.predict(X_test)
precision_cat = precision_score(y_test, y_pred,average='macro')
accuracy_cat = accuracy_score(y_test, y_pred)
f1_cat = f1_score(y_test, y_pred,average='macro')
recall_cat = recall_score(y_test, y_pred,average='macro')
print(precision_cat)
print(accuracy_cat)
print(f1_cat)
print(recall_cat)

# %%
y_pred = rforest_normal.predict(X_test)
precision_r = precision_score(y_test, y_pred,average='macro')
accuracy_r = accuracy_score(y_test, y_pred)
f1_r = f1_score(y_test, y_pred,average='macro')
recall_r = recall_score(y_test, y_pred,average='macro')
print(precision_r)
print(accuracy_r)
print(f1_r)
print(recall_r)

# %%
y_pred = ada1.predict(X_test)
precision_ada = precision_score(y_test, y_pred,average='macro')
accuracy_ada = accuracy_score(y_test, y_pred)
f1_ada = f1_score(y_test, y_pred,average='macro')
recall_ada = recall_score(y_test, y_pred,average='macro')
print(precision_ada)
print(accuracy_ada)
print(f1_ada)
print(recall_ada)

# %%
y_pred = sgd_final.predict(X_test)
precision_sgd = precision_score(y_test, y_pred,average='macro')
accuracy_sgd = accuracy_score(y_test, y_pred)
f1_sgd = f1_score(y_test, y_pred,average='macro')
recall_sgd = recall_score(y_test, y_pred,average='macro')
print(precision_sgd)
print(accuracy_sgd)
print(f1_sgd)
print(recall_sgd)

# %%
y_pred = gaussian_NB_final.predict(X_test)
precision_gaussian = precision_score(y_test, y_pred,average='macro')
accuracy_gaussian = accuracy_score(y_test, y_pred)
f1_gaussian = f1_score(y_test, y_pred,average='macro')
recall_gaussian = recall_score(y_test, y_pred,average='macro')
print(precision_gaussian)
print(accuracy_gaussian)
print(f1_gaussian)
print(recall_gaussian)
